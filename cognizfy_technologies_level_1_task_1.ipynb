# %% [markdown]
# <a href="https://colab.research.google.com/github/Sujald06/Sujald06/blob/main/cognizfy_technologies_level_1_task_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
#Importing All Necessary Libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("Dataset .csv")  #Loading the Dataset.csv
df
# Out:
#       Restaurant ID           Restaurant Name  Country Code              City  \
# 0           6317637          Le Petit Souffle           162       Makati City
# 1           6304287          Izakaya Kikufuji           162       Makati City
# 2           6300002    Heat - Edsa Shangri-La           162  Mandaluyong City
# 3           6318506                      Ooma           162  Mandaluyong City
# 4           6314302               Sambo Kojin           162  Mandaluyong City
# ...             ...                       ...           ...               ...
# 9546        5915730               Naml۱ Gurme           208         ��stanbul
# 9547        5908749              Ceviz A��ac۱           208         ��stanbul
# 9548        5915807                     Huqqa           208         ��stanbul
# 9549        5916112               A���k Kahve           208         ��stanbul
# 9550        5927402  Walter's Coffee Roastery           208         ��stanbul
#
# ...

# %%
df.head() # It will Retrieve Top-5
# Out:
#    Restaurant ID         Restaurant Name  Country Code              City  \
# 0        6317637        Le Petit Souffle           162       Makati City
# 1        6304287        Izakaya Kikufuji           162       Makati City
# 2        6300002  Heat - Edsa Shangri-La           162  Mandaluyong City
# 3        6318506                    Ooma           162  Mandaluyong City
# 4        6314302             Sambo Kojin           162  Mandaluyong City
#
#                                              Address  \
# 0  Third Floor, Century City Mall, Kalayaan Avenu...
# 1  Little Tokyo, 2277 Chino Roces Avenue, Legaspi...
# 2  Edsa Shangri-La, 1 Garden Way, Ortigas, Mandal...
# 3  Third Floor, Mega Fashion Hall, SM Megamall, O...
# 4  Third Floor, Mega Atrium, SM Megamall, Ortigas...
#
#                                      Locality  \
# 0   Century City Mall, Poblacion, Makati City
# 1  Little Tokyo, Legaspi Village, Makati City
# 2  Edsa Shangri-La, Ortigas, Mandaluyong City
# ...

# %%
df.tail()# It will Retrieve Last-5
# Out:
#       Restaurant ID           Restaurant Name  Country Code       City  \
# 9546        5915730               Naml۱ Gurme           208  ��stanbul
# 9547        5908749              Ceviz A��ac۱           208  ��stanbul
# 9548        5915807                     Huqqa           208  ��stanbul
# 9549        5916112               A���k Kahve           208  ��stanbul
# 9550        5927402  Walter's Coffee Roastery           208  ��stanbul
#
#                                                 Address     Locality  \
# 9546  Kemanke�� Karamustafa Pa��a Mahallesi, R۱ht۱m ...     Karak�_y
# 9547  Ko��uyolu Mahallesi, Muhittin ��st�_nda�� Cadd...    Ko��uyolu
# 9548  Kuru�_e��me Mahallesi, Muallim Naci Caddesi, N...  Kuru�_e��me
# 9549  Kuru�_e��me Mahallesi, Muallim Naci Caddesi, N...  Kuru�_e��me
# 9550  Cafea��a Mahallesi, Bademalt۱ Sokak, No 21/B, ...         Moda
#
#             Locality Verbose  Longitude   Latitude  \
# 9546     Karak�_y, ��stanbul  28.977392  41.022793
# ...

# %%
Cuisine_counts = df['Cuisines'].value_counts()  # Cuisines value counts
Cuisine_counts
# Out:
# Cuisines
# North Indian                          936
# North Indian, Chinese                 511
# Chinese                               354
# Fast Food                             354
# North Indian, Mughlai                 334
#                                      ...
# World Cuisine, Patisserie, Cafe         1
# Burger, Izgara                          1
# Desserts, B�_rek                        1
# Restaurant Cafe, Turkish, Desserts      1
# Restaurant Cafe, Desserts               1
# Name: count, Length: 1825, dtype: int64

# %%
top_Cuisines = Cuisine_counts.head(3) #Top 3 Cuisines
top_Cuisines
# Out:
# Cuisines
# North Indian             936
# North Indian, Chinese    511
# Chinese                  354
# Name: count, dtype: int64

# %%
top_Cuisines = df['Cuisines'].str.split(',', expand=True).stack().value_counts()

# %%
Top_3_Cuisines = top_Cuisines.head(3)
print(Top_3_Cuisines)
# Out:
# North Indian    2992
#  Chinese        1880
#  Fast Food      1314
# Name: count, dtype: int64

# %%
Top_3_Cuisines = Top_3_Cuisines.sort_values(ascending=False)

colors = ['red', 'orange', 'blue']  # Define the colors for the bars

plt.bar(Top_3_Cuisines.index, Top_3_Cuisines.values, color=colors) # Plot the bar chart with colors

# Add labels and title
plt.xlabel('Cuisine')
plt.ylabel('Count')
plt.title('Top 3 Cuisines')
plt.show()# Show the chart

# %%
top_restaurents=len(df)   # No of percentage in Cuisines top 3 columns
percentage_per_cuisine=(Top_3_Cuisines/top_restaurents)*100
print(percentage_per_cuisine)
# Out:
# North Indian    31.326563
#  Chinese        19.683803
#  Fast Food      13.757722
# Name: count, dtype: float64

# %%
print( 'percentage of restaurants for top three cusines')
percentage_per_cuisine
# Out:
# percentage of restaurants for top three cusines
# North Indian    31.326563
#  Chinese        19.683803
#  Fast Food      13.757722
# Name: count, dtype: float64

# %%
fig,ax=plt.subplots(figsize=(10,6))
ab=sns.barplot(x=percentage_per_cuisine.index,y=percentage_per_cuisine.values)
for bar in ab.containers[0]:
  height=bar.get_height()
  ab.annotate(f'{height:.2f}%',xy=(bar.get_x()+bar.get_width()/2,height),xytext=(0,3),textcoords='offset points',ha='center',va='bottom')
plt.title('Percentage of Restaurants Serving Top Three Cuisines')
# Out:
# Text(0.5, 1.0, 'Percentage of Restaurants Serving Top Three Cuisines')
